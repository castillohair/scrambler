# %%
import keras
from keras.models import Sequential, Model, load_model

import os
import pickle
import numpy as np
import pandas as pd

import scipy.sparse as sp
import scipy.io as spio

import matplotlib.pyplot as plt

from scrambler.models import *
from scrambler.utils import OneHotEncoder, get_sequence_masks
from scrambler.visualizations import plot_dna_logo, plot_dna_importance_scores

from apa_utils import load_apa_data, load_apa_predictor_cleavage_logodds, animate_apa_examples
# Out:
# 2021-12-08 22:33:04.745053: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.10.1
# WARNING:tensorflow:From /home/ubuntu/anaconda3/envs/test_gpu_2/lib/python3.9/site-packages/tensorflow/python/compat/v2_compat.py:96: disable_resource_variables (from tensorflow.python.ops.variable_scope) is deprecated and will be removed in a future version.
# Instructions for updating:
# non-resource variables are not supported in the long term
# 2021-12-08 22:33:07.516820: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2 AVX AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2021-12-08 22:33:07.518454: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcuda.so.1
# 2021-12-08 22:33:07.580217: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-12-08 22:33:07.581184: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1720] Found device 0 with properties:
# pciBusID: 0000:00:1e.0 name: Tesla V100-SXM2-16GB computeCapability: 7.0
# coreClock: 1.53GHz coreCount: 80 deviceMemorySize: 15.78GiB deviceMemoryBandwidth: 836.37GiB/s
# 2021-12-08 22:33:07.581220: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.10.1
# 2021-12-08 22:33:07.583457: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublas.so.10
# 2021-12-08 22:33:07.583522: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublasLt.so.10
# 2021-12-08 22:33:07.585334: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcufft.so.10
# 2021-12-08 22:33:07.585667: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcurand.so.10
# 2021-12-08 22:33:07.587767: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcusolver.so.10
# 2021-12-08 22:33:07.589024: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcusparse.so.10
# 2021-12-08 22:33:07.593503: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudnn.so.7
# 2021-12-08 22:33:07.593636: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-12-08 22:33:07.594623: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-12-08 22:33:07.595527: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1862] Adding visible gpu devices: 0
# 2021-12-08 22:33:07.595606: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.10.1
# 2021-12-08 22:33:08.295776: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1261] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2021-12-08 22:33:08.295826: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1267]      0
# 2021-12-08 22:33:08.295864: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1280] 0:   N
# 2021-12-08 22:33:08.296138: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-12-08 22:33:08.297122: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-12-08 22:33:08.298080: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-12-08 22:33:08.298987: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1406] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 14764 MB memory) -> physical GPU (device: 0, name: Tesla V100-SXM2-16GB, pci bus id: 0000:00:1e.0, compute capability: 7.0)
# 2021-12-08 22:33:08.299293: I tensorflow/compiler/jit/xla_gpu_device.cc:99] Not creating XLA devices, tf_xla_enable_xla_devices not set

# %%
#Load APA data and predictor

encoder = OneHotEncoder(seq_length=205, channel_map={'A' : 0, 'C' : 1, 'G' : 2, 'T' : 3})

data_path = 'apa_doubledope_cached_set.csv'

x_train, y_train, x_test, y_test = load_apa_data(data_path, encoder)

predictor_path = 'saved_models/aparent_plasmid_iso_cut_distalpas_all_libs_no_sampleweights_sgd.h5'

predictor = load_apa_predictor_cleavage_logodds(predictor_path)
# Out:
# len(data_df) = 34748 (loaded)
# x_train.shape = (32992, 1, 205, 4)
# x_test.shape = (1728, 1, 205, 4)
# y_train.shape = (32992, 1)
# y_test.shape = (1728, 1)
# 2021-12-08 22:33:13.333578: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:196] None of the MLIR optimization passes are enabled (registered 0 passes)
# 2021-12-08 22:33:13.351994: I tensorflow/core/platform/profile_utils/cpu_utils.cc:112] CPU Frequency: 2300015000 Hz

# %%
#Print predictor input/output details

print("predictor.inputs = " + str(predictor.inputs))
print("predictor.outputs = " + str(predictor.outputs))
# Out:
# predictor.inputs = [<tf.Tensor 'seq_input:0' shape=(?, 205, 4) dtype=float32>, <tf.Tensor 'lib_input:0' shape=(?, 13) dtype=float32>, <tf.Tensor 'distal_pas_input:0' shape=(?, 1) dtype=float32>]
# predictor.outputs = [<tf.Tensor 'rel_cut_logodds/Log:0' shape=(?, 4) dtype=float32>]

# %%
#Define sequence template and background

sequence_template = 'CTTCCGATCT$$$$$$$$$$$$$$$$$$$$CATTACTCGCATCCA$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$CAGCCAATTAAGCC$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$CTAC'

pseudo_count = 1.0

onehot_template = encoder(sequence_template)[None, ...]
sequence_mask = get_sequence_masks([sequence_template])[0]

x_mean = (np.sum(x_train, axis=(0, 1)) + pseudo_count) / (x_train.shape[0] + 4. * pseudo_count)

# %%
#Visualize background sequence distribution

plot_dna_logo(np.copy(x_mean), sequence_template=sequence_template, figsize=(14, 0.65), logo_height=1.0, plot_start=0, plot_end=205)

# %%
#Calculate mean training set kl-divergence against background

x_train_clipped = np.clip(np.copy(x_train[:, 0, :, :]), 1e-8, 1. - 1e-8)

kl_divs = np.sum(x_train_clipped * np.log(x_train_clipped / np.tile(np.expand_dims(x_mean, axis=0), (x_train_clipped.shape[0], 1, 1))), axis=-1) / np.log(2.0)

x_mean_kl_divs = np.sum(kl_divs * sequence_mask, axis=-1) / np.sum(sequence_mask)
x_mean_kl_div = np.mean(x_mean_kl_divs)

print("Mean KL Div against background (bits) = " + str(x_mean_kl_div))
# Out:
# Mean KL Div against background (bits) = 1.8729476983107292

# %%
#For the sake of the example, lets transform x to a 1d shape

x_train = x_train[:, 0, ...]
x_test = x_test[:, 0, ...]

print(x_train.shape)
print(x_test.shape)
# Out:
# (32992, 205, 4)
# (1728, 205, 4)

# %%
#Create extra inputs that the predictor model expects

feat_1_train = np.zeros((x_train.shape[0], 13))
feat_1_test = np.zeros((x_test.shape[0], 13))
feat_1_train[:, 4] = 1.
feat_1_test[:, 4] = 1.

feat_2_train = np.ones((x_train.shape[0], 1))
feat_2_test = np.ones((x_test.shape[0], 1))

print(feat_1_train.shape)
print(feat_2_train.shape)
# Out:
# (32992, 13)
# (32992, 1)

# %%
#Scrambler network configuration
network_config = {
    'n_groups' : 5,
    'n_resblocks_per_group' : 4,
    'n_channels' : 32,
    'window_size' : 3,
    'dilation_rates' : [1, 2, 4, 2, 1],
    'drop_rate' : 0.0,
    'norm_mode' : 'instance',
    'mask_smoothing' : True,
    'mask_smoothing_window_size' : 5,
    'mask_smoothing_std' : 1.,
    'mask_drop_scales' : [1, 5],
    'mask_min_drop_rate' : 0.0,
    'mask_max_drop_rate' : 0.5,
    'label_input' : False
}

# %%
#Train scrambler(s) to maximize cleavage logodds at different positions

save_dir = 'saved_models'

for cut_pos in [0, 1, 2, 3] :

    print("Training scrambler for cleavage position = " + str(cut_pos) + ".")
    
    #Initialize scrambler
    scrambler = Scrambler(
        scrambler_mode='inclusion',
        input_size_x=None,
        input_size_y=205,
        n_out_channels=4,
        n_classes=4,
        input_templates=[onehot_template],
        input_backgrounds=[x_mean],
        batch_size=32,
        n_samples=32,
        sample_mode='gumbel',
        zeropad_input=False,
        mask_dropout=False,
        network_config=network_config
    )

    #y_pred_scrambled.shape = (batch_size, n_samples, n_classes)
    def maximize_cleavage_logodds(y_pred_non_scrambled, y_pred_scrambled, cut_pos=cut_pos) :

        return -K.mean(y_pred_scrambled[..., cut_pos], axis=-1)

    n_epochs = 10

    _ = scrambler.train(
        predictor,
        x_train,
        y_train,
        x_test,
        y_test,
        n_epochs,
        extra_input_train=[feat_1_train, feat_2_train],
        extra_input_test=[feat_1_test, feat_2_test],
        monitor_test_indices=None,
        custom_loss_func=maximize_cleavage_logodds,
        entropy_mode='target',
        entropy_bits=0.1,
        entropy_weight=20.
    )
    
    #Save scrambler checkpoint

    model_name = 'apa_inclusion_scrambler_smooth_target_bits_01_epochs_10_deeper_cut_pos_' + str(cut_pos)

    if not os.path.isdir(save_dir):
        os.makedirs(save_dir)

    model_path = os.path.join(save_dir, model_name + '.h5')

    scrambler.save_model(model_path)
# Out:
# Training scrambler for cleavage position = 0.
# Train on 32992 samples, validate on 1728 samples
# Epoch 1/10
# 32992/32992 [==============================] - 48s 1ms/sample - loss: 3.7865 - nll_loss: 3.3311 - entropy_loss: 0.4554 - val_loss: 3.2748 - val_nll_loss: 3.1947 - val_entropy_loss: 0.0800
# Epoch 2/10
# 32992/32992 [==============================] - 48s 1ms/sample - loss: 3.2224 - nll_loss: 3.1654 - entropy_loss: 0.0570 - val_loss: 3.1827 - val_nll_loss: 3.1087 - val_entropy_loss: 0.0741
# Epoch 3/10
# 32992/32992 [==============================] - 60s 2ms/sample - loss: 3.1521 - nll_loss: 3.0913 - entropy_loss: 0.0608 - val_loss: 3.1395 - val_nll_loss: 3.1066 - val_entropy_loss: 0.0328
# Epoch 4/10
# 32992/32992 [==============================] - 61s 2ms/sample - loss: 3.1169 - nll_loss: 3.0546 - entropy_loss: 0.0623 - val_loss: 3.1052 - val_nll_loss: 3.0515 - val_entropy_loss: 0.0538
# Epoch 5/10
# 32992/32992 [==============================] - 61s 2ms/sample - loss: 3.0922 - nll_loss: 3.0283 - entropy_loss: 0.0639 - val_loss: 3.0940 - val_nll_loss: 3.0594 - val_entropy_loss: 0.0346
# Epoch 6/10
# 32992/32992 [==============================] - 61s 2ms/sample - loss: 3.0699 - nll_loss: 3.0025 - entropy_loss: 0.0674 - val_loss: 3.0657 - val_nll_loss: 2.9816 - val_entropy_loss: 0.0841
# Epoch 7/10
# 32992/32992 [==============================] - 61s 2ms/sample - loss: 3.0572 - nll_loss: 2.9897 - entropy_loss: 0.0675 - val_loss: 3.0567 - val_nll_loss: 2.9784 - val_entropy_loss: 0.0783
# Epoch 8/10
# 32992/32992 [==============================] - 49s 1ms/sample - loss: 3.0488 - nll_loss: 2.9814 - entropy_loss: 0.0674 - val_loss: 3.0498 - val_nll_loss: 2.9906 - val_entropy_loss: 0.0592
# Epoch 9/10
# 32992/32992 [==============================] - 42s 1ms/sample - loss: 3.0418 - nll_loss: 2.9745 - entropy_loss: 0.0673 - val_loss: 3.0449 - val_nll_loss: 2.9718 - val_entropy_loss: 0.0730
# Epoch 10/10
# 32992/32992 [==============================] - 41s 1ms/sample - loss: 3.0367 - nll_loss: 2.9690 - entropy_loss: 0.0677 - val_loss: 3.0401 - val_nll_loss: 2.9614 - val_entropy_loss: 0.0787
# Saved scrambler model at saved_models/apa_inclusion_scrambler_smooth_target_bits_01_epochs_10_deeper_cut_pos_0.h5
# Training scrambler for cleavage position = 1.
# Train on 32992 samples, validate on 1728 samples
# Epoch 1/10
# 32992/32992 [==============================] - 48s 1ms/sample - loss: 1.5463 - nll_loss: 1.3952 - entropy_loss: 0.1511 - val_loss: 1.4171 - val_nll_loss: 1.3859 - val_entropy_loss: 0.0312
# Epoch 2/10
# 32992/32992 [==============================] - 42s 1ms/sample - loss: 1.4019 - nll_loss: 1.3769 - entropy_loss: 0.0250 - val_loss: 1.3939 - val_nll_loss: 1.3748 - val_entropy_loss: 0.0191
# Epoch 3/10
# 32992/32992 [==============================] - 43s 1ms/sample - loss: 1.3858 - nll_loss: 1.3670 - entropy_loss: 0.0188 - val_loss: 1.3824 - val_nll_loss: 1.3675 - val_entropy_loss: 0.0149
# Epoch 4/10
# 32992/32992 [==============================] - 44s 1ms/sample - loss: 1.3713 - nll_loss: 1.3534 - entropy_loss: 0.0180 - val_loss: 1.3560 - val_nll_loss: 1.3389 - val_entropy_loss: 0.0172
# Epoch 5/10
# 32992/32992 [==============================] - 43s 1ms/sample - loss: 1.3214 - nll_loss: 1.2964 - entropy_loss: 0.0250 - val_loss: 1.2707 - val_nll_loss: 1.2325 - val_entropy_loss: 0.0381
# Epoch 6/10
# 32992/32992 [==============================] - 41s 1ms/sample - loss: 1.2444 - nll_loss: 1.2208 - entropy_loss: 0.0236 - val_loss: 1.2258 - val_nll_loss: 1.2042 - val_entropy_loss: 0.0216
# Epoch 7/10
# 32992/32992 [==============================] - 42s 1ms/sample - loss: 1.2160 - nll_loss: 1.1943 - entropy_loss: 0.0216 - val_loss: 1.1890 - val_nll_loss: 1.1675 - val_entropy_loss: 0.0215
# Epoch 8/10
# 32992/32992 [==============================] - 42s 1ms/sample - loss: 1.1583 - nll_loss: 1.1320 - entropy_loss: 0.0262 - val_loss: 1.1410 - val_nll_loss: 1.1172 - val_entropy_loss: 0.0238
# Epoch 9/10
# 32992/32992 [==============================] - 42s 1ms/sample - loss: 1.1346 - nll_loss: 1.1091 - entropy_loss: 0.0255 - val_loss: 1.1288 - val_nll_loss: 1.1044 - val_entropy_loss: 0.0245
# Epoch 10/10
# 32992/32992 [==============================] - 42s 1ms/sample - loss: 1.1269 - nll_loss: 1.1022 - entropy_loss: 0.0247 - val_loss: 1.1226 - val_nll_loss: 1.1033 - val_entropy_loss: 0.0193
# Saved scrambler model at saved_models/apa_inclusion_scrambler_smooth_target_bits_01_epochs_10_deeper_cut_pos_1.h5
# Training scrambler for cleavage position = 2.
# Train on 32992 samples, validate on 1728 samples
# Epoch 1/10
# 32992/32992 [==============================] - 50s 2ms/sample - loss: 3.6232 - nll_loss: 3.4760 - entropy_loss: 0.1472 - val_loss: 3.3833 - val_nll_loss: 3.3307 - val_entropy_loss: 0.0526
# Epoch 2/10
# 32992/32992 [==============================] - 43s 1ms/sample - loss: 3.3189 - nll_loss: 3.2690 - entropy_loss: 0.0499 - val_loss: 3.2397 - val_nll_loss: 3.1945 - val_entropy_loss: 0.0452
# Epoch 3/10
# 32992/32992 [==============================] - 43s 1ms/sample - loss: 3.1915 - nll_loss: 3.1372 - entropy_loss: 0.0543 - val_loss: 3.1605 - val_nll_loss: 3.1171 - val_entropy_loss: 0.0435
# Epoch 4/10
# 32992/32992 [==============================] - 43s 1ms/sample - loss: 3.1427 - nll_loss: 3.0842 - entropy_loss: 0.0585 - val_loss: 3.1266 - val_nll_loss: 3.0783 - val_entropy_loss: 0.0483
# Epoch 5/10
# 32992/32992 [==============================] - 43s 1ms/sample - loss: 3.1215 - nll_loss: 3.0618 - entropy_loss: 0.0597 - val_loss: 3.1095 - val_nll_loss: 3.0370 - val_entropy_loss: 0.0725
# Epoch 6/10
# 32992/32992 [==============================] - 43s 1ms/sample - loss: 3.1071 - nll_loss: 3.0452 - entropy_loss: 0.0619 - val_loss: 3.1022 - val_nll_loss: 3.0529 - val_entropy_loss: 0.0493
# Epoch 7/10
# 32992/32992 [==============================] - 43s 1ms/sample - loss: 3.0968 - nll_loss: 3.0347 - entropy_loss: 0.0621 - val_loss: 3.0873 - val_nll_loss: 3.0210 - val_entropy_loss: 0.0663
# Epoch 8/10
# 32992/32992 [==============================] - 43s 1ms/sample - loss: 3.0878 - nll_loss: 3.0252 - entropy_loss: 0.0626 - val_loss: 3.0813 - val_nll_loss: 3.0145 - val_entropy_loss: 0.0668
# Epoch 9/10
# 32992/32992 [==============================] - 42s 1ms/sample - loss: 3.0804 - nll_loss: 3.0174 - entropy_loss: 0.0630 - val_loss: 3.0809 - val_nll_loss: 3.0377 - val_entropy_loss: 0.0433
# Epoch 10/10
# 32992/32992 [==============================] - 43s 1ms/sample - loss: 3.0758 - nll_loss: 3.0125 - entropy_loss: 0.0633 - val_loss: 3.0715 - val_nll_loss: 3.0064 - val_entropy_loss: 0.0652
# Saved scrambler model at saved_models/apa_inclusion_scrambler_smooth_target_bits_01_epochs_10_deeper_cut_pos_2.h5
# Training scrambler for cleavage position = 3.
# Train on 32992 samples, validate on 1728 samples
# Epoch 1/10
# 32992/32992 [==============================] - 52s 2ms/sample - loss: 4.4001 - nll_loss: 4.0948 - entropy_loss: 0.3052 - val_loss: 4.0252 - val_nll_loss: 3.9712 - val_entropy_loss: 0.0540
# Epoch 2/10
# 32992/32992 [==============================] - 43s 1ms/sample - loss: 3.9238 - nll_loss: 3.8379 - entropy_loss: 0.0859 - val_loss: 3.8545 - val_nll_loss: 3.7880 - val_entropy_loss: 0.0664
# Epoch 3/10
# 32992/32992 [==============================] - 44s 1ms/sample - loss: 3.8105 - nll_loss: 3.7177 - entropy_loss: 0.0928 - val_loss: 3.7746 - val_nll_loss: 3.7016 - val_entropy_loss: 0.0730
# Epoch 4/10
# 32992/32992 [==============================] - 44s 1ms/sample - loss: 3.7449 - nll_loss: 3.6431 - entropy_loss: 0.1018 - val_loss: 3.7283 - val_nll_loss: 3.5994 - val_entropy_loss: 0.1289
# Epoch 5/10
# 32992/32992 [==============================] - 44s 1ms/sample - loss: 3.7044 - nll_loss: 3.5980 - entropy_loss: 0.1064 - val_loss: 3.6945 - val_nll_loss: 3.6063 - val_entropy_loss: 0.0882
# Epoch 6/10
# 32992/32992 [==============================] - 43s 1ms/sample - loss: 3.6803 - nll_loss: 3.5706 - entropy_loss: 0.1096 - val_loss: 3.6749 - val_nll_loss: 3.5621 - val_entropy_loss: 0.1128
# Epoch 7/10
# 32992/32992 [==============================] - 44s 1ms/sample - loss: 3.6503 - nll_loss: 3.5352 - entropy_loss: 0.1150 - val_loss: 3.6383 - val_nll_loss: 3.5300 - val_entropy_loss: 0.1083
# Epoch 8/10
# 32992/32992 [==============================] - 43s 1ms/sample - loss: 3.6238 - nll_loss: 3.5054 - entropy_loss: 0.1184 - val_loss: 3.6256 - val_nll_loss: 3.4878 - val_entropy_loss: 0.1378
# Epoch 9/10
# 32992/32992 [==============================] - 44s 1ms/sample - loss: 3.6104 - nll_loss: 3.4906 - entropy_loss: 0.1197 - val_loss: 3.6100 - val_nll_loss: 3.5006 - val_entropy_loss: 0.1094
# Epoch 10/10
# 32992/32992 [==============================] - 44s 1ms/sample - loss: 3.5933 - nll_loss: 3.4693 - entropy_loss: 0.1240 - val_loss: 3.5935 - val_nll_loss: 3.4747 - val_entropy_loss: 0.1189
# Saved scrambler model at saved_models/apa_inclusion_scrambler_smooth_target_bits_01_epochs_10_deeper_cut_pos_3.h5

# %%
#Load models and interpret test patterns for all cleavage positions

save_dir = 'saved_models'

pwm_test = []
sample_test = []
importance_scores_test = []

for cut_pos in [0, 1, 2, 3] :

    print("Interpreting for cleavage position = " + str(cut_pos) + ".")

    model_name = 'apa_inclusion_scrambler_smooth_target_bits_01_epochs_10_deeper_cut_pos_' + str(cut_pos)
    model_path = os.path.join(save_dir, model_name + '.h5')

    scrambler.load_model(model_path)
    
    #Interpret the test set using the trained scrambler
    pwm_t, sample_t, importance_scores_t = scrambler.interpret(x_test)

    pwm_test.append(pwm_t[None, ...])
    sample_test.append(sample_t[None, ...])
    importance_scores_test.append(importance_scores_t[None, ...])

pwm_test = np.concatenate(pwm_test, axis=0)
sample_test = np.concatenate(sample_test, axis=0)
importance_scores_test = np.concatenate(importance_scores_test, axis=0)
# Out:
# Interpreting for cleavage position = 0.
# Loaded scrambler model from saved_models/apa_inclusion_scrambler_smooth_target_bits_01_epochs_10_deeper_cut_pos_0.h5
# Interpreting for cleavage position = 1.
# Loaded scrambler model from saved_models/apa_inclusion_scrambler_smooth_target_bits_01_epochs_10_deeper_cut_pos_1.h5
# Interpreting for cleavage position = 2.
# Loaded scrambler model from saved_models/apa_inclusion_scrambler_smooth_target_bits_01_epochs_10_deeper_cut_pos_2.h5
# Interpreting for cleavage position = 3.
# Loaded scrambler model from saved_models/apa_inclusion_scrambler_smooth_target_bits_01_epochs_10_deeper_cut_pos_3.h5

# %%
#Visualize a few reconstructed sequence patterns

importance_scores_test *= sequence_mask[None, None, :, None]

plot_examples = [3, 5, 6]
save_examples = []

cuts = [76 + 5, 76 + 15, 76 + 25, 76 + 35]

for test_ix in plot_examples :
    
    print("Test sequence " + str(test_ix) + ":")
    
    save_figs = False
    if save_examples is not None and test_ix in save_examples :
        save_figs = True
    
    plot_dna_logo(x_test[test_ix, :, :], sequence_template=sequence_template, figsize=(14, 0.65), plot_start=0, plot_end=205, plot_sequence_template=True, save_figs=save_figs, fig_name=model_name + "_test_ix_" + str(test_ix) + "_orig_sequence")
    
    #Plot interpretation PWM for each cleavage position
    for cut_ix, cut_pos in enumerate([0, 1, 2, 3]) :
        #Mark the position where we are maximizing cleavage
        cut_template = 'N' * 205
        cut_template = cut_template[:cuts[cut_ix]] + 'CCC' + cut_template[cuts[cut_ix]+1:]
        plot_dna_logo(np.zeros((205, 4)), sequence_template=cut_template, figsize=(14, 0.65), plot_start=0, plot_end=205, plot_sequence_template=True, save_figs=save_figs, fig_name=model_name + "_test_ix_" + str(test_ix) + "_scrambld_pwm")
        #Plot Scrambler interpretation (PWM)
        plot_dna_logo(pwm_test[cut_ix, test_ix, :, :], sequence_template=sequence_template, figsize=(14, 0.65), plot_start=0, plot_end=205, plot_sequence_template=True, save_figs=save_figs, fig_name=model_name + "_test_ix_" + str(test_ix) + "_scrambld_pwm")
# Out:
# Test sequence 3:
# Test sequence 5:
# Test sequence 6:
